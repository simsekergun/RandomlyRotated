# %% [markdown]
# <a href="https://colab.research.google.com/github/simsekergun/RandomlyRotated/blob/main/Classification_RandomlyRotatedScatterer_XGB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import xgboost as xgb
from sklearn.metrics import accuracy_score, classification_report
import time

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# %%
url1 = 'https://raw.githubusercontent.com/simsekergun/RandomlyRotated/refs/heads/main/MNIST_rot_SIM1.csv'
df1 = pd.read_csv(url1, index_col=0)

url2 = 'https://raw.githubusercontent.com/simsekergun/RandomlyRotated/refs/heads/main/MNIST_rot_SIM2.csv'
df2 = pd.read_csv(url2, index_col=0)

url3 = 'https://raw.githubusercontent.com/simsekergun/RandomlyRotated/refs/heads/main/MNIST_rot_SIM3.csv'
df3 = pd.read_csv(url3, index_col=0)

url4 = 'https://raw.githubusercontent.com/simsekergun/RandomlyRotated/refs/heads/main/MNIST_rot_SIM4.csv'
df4 = pd.read_csv(url4, index_col=0)

url5 = 'https://raw.githubusercontent.com/simsekergun/RandomlyRotated/refs/heads/main/MNIST_rot_SIM5.csv'
df5 = pd.read_csv(url5, index_col=0)

url6 = 'https://raw.githubusercontent.com/simsekergun/RandomlyRotated/refs/heads/main/MNIST_rot_SIM6.csv'
df6 = pd.read_csv(url6, index_col=0)

url7 = 'https://raw.githubusercontent.com/simsekergun/RandomlyRotated/refs/heads/main/MNIST_rot_SIM7.csv'
df7 = pd.read_csv(url7, index_col=0)

url8 = 'https://raw.githubusercontent.com/simsekergun/RandomlyRotated/refs/heads/main/MNIST_rot_SIM8.csv'
df8 = pd.read_csv(url8, index_col=0)

url9 = 'https://raw.githubusercontent.com/simsekergun/RandomlyRotated/refs/heads/main/MNIST_rot_SIM9.csv'
df9 = pd.read_csv(url9, index_col=0)

url10 = 'https://raw.githubusercontent.com/simsekergun/RandomlyRotated/refs/heads/main/MNIST_rot_SIM10.csv'
df10 = pd.read_csv(url10, index_col=0)

url11 = 'https://raw.githubusercontent.com/simsekergun/RandomlyRotated/refs/heads/main/MNIST_rot_SIM11.csv'
df11 = pd.read_csv(url11, index_col=0)

url12 = 'https://raw.githubusercontent.com/simsekergun/RandomlyRotated/refs/heads/main/MNIST_rot_SIM12.csv'
df12 = pd.read_csv(url12, index_col=0)

df_all = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12], axis=0)

# Reset the index
df_all = df_all.reset_index(drop=True)

print(f"Combined Shape: {df_all.shape}")

# View the first few rows
df_all.head()
# Out:
# Combined Shape: (12000, 65)
#               0             1             2             3             4  \
# 0  8.599444e-20 -6.231016e-19 -6.933704e-19 -2.736925e-19  4.245287e-20
# 1  3.137589e-20 -6.429994e-19 -8.023542e-19 -5.501632e-19 -4.509170e-19
# 2 -1.326605e-20 -4.580125e-19 -2.876271e-19  8.287229e-20  1.161408e-19
# 3  1.155195e-19 -2.451452e-19 -2.715376e-19 -1.088131e-19  5.316636e-20
# 4 -5.492622e-20 -7.036797e-19 -4.647136e-19 -4.597923e-20  1.422098e-19
#
#               5             6             7             8             9  ...  \
# 0  1.006229e-19  9.058320e-20  1.892554e-19  1.105886e-19 -2.186010e-19  ...
# 1 -6.149811e-19 -6.402798e-19 -2.548319e-19  6.587843e-20  3.990638e-19  ...
# 2 -2.394476e-19 -4.567253e-19 -3.680656e-19 -1.405961e-19  1.693667e-19  ...
# 3  2.419866e-19  2.123935e-19  4.197650e-20 -1.450483e-19 -2.382157e-19  ...
# 4  1.169888e-19 -1.251926e-20 -7.236105e-20  3.206697e-20  1.285730e-19  ...
#
#              55            56            57            58            59  \
# 0 -1.513291e-18 -1.553155e-18 -1.459761e-18 -1.688467e-19  1.982808e-18
# 1 -2.246684e-18 -2.292242e-18 -1.992845e-18 -4.320242e-19  1.900514e-18
# 2 -1.867904e-18 -2.064785e-18 -2.134977e-18 -7.622166e-19  1.709335e-18
# 3 -1.531262e-18 -1.838182e-18 -1.980286e-18 -6.558416e-19  1.871363e-18
# 4 -1.899248e-18 -1.930469e-18 -1.751551e-18 -4.451874e-19  1.822326e-18
#
#              60            61            62            63  64
# 0  6.879230e-19 -1.795921e-18 -4.888217e-19  1.745913e-18   5
# 1  6.989732e-19 -1.842764e-18 -6.105473e-19  1.613595e-18   0
# 2  8.240770e-19 -1.593208e-18 -5.260953e-19  1.548896e-18   4
# 3  7.939170e-19 -1.757816e-18 -7.118855e-19  1.296885e-18   1
# 4  7.606922e-19 -1.651533e-18 -4.209629e-19  1.823976e-18   9
#
# [5 rows x 65 columns]

# %%
# 2. Separate Features (X) and Target (y)
# We take the first 64 columns for X
X = df_all.iloc[:, 0:64].values

# We take the last column for y (index -1)
# We convert it to integers
y = df_all.iloc[:, -1].astype(int).values

# 3. Create the 90% Training and 10% Testing split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.10, train_size=0.90, random_state=42
)

# Verify the shapes
print(f"Total samples: {len(df_all)}")
print(f"X_train shape: {X_train.shape}") # Should be (N*0.9, 64)
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape:  {X_test.shape}")  # Should be (N*0.1, 64)
print(f"y_test shape:  {y_test.shape}")
# Out:
# Total samples: 12000
# X_train shape: (10800, 64)
# y_train shape: (10800,)
# X_test shape:  (1200, 64)
# y_test shape:  (1200,)

# %%
# 1. Initialize the scaler
scaler = StandardScaler()

# 2. Fit on training data and transform both sets
# to ensure both sets have a mean of 0 and a standard deviation of 1
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 3. Reshape for the CNN (16 positions, 4 components)
X_train_cnn = X_train_scaled.reshape(-1, 16, 4)
X_test_cnn = X_test_scaled.reshape(-1, 16, 4)

# %% [markdown]
# ## XGB
#
# Initial test (before hyperparameter tuning)

# %%
# 1. Prepare Data: Flatten (16, 4) -> (64,)
X_train_xgb = X_train_cnn.reshape(X_train_cnn.shape[0], -1)
X_test_xgb = X_test_cnn.reshape(X_test_cnn.shape[0], -1)

# 2. Initialize the XGBClassifier
# We set objective to 'multi:softprob' for multi-class classification
xgb_model = xgb.XGBClassifier(
    n_estimators=100,      # Number of boosting rounds (trees)
    learning_rate=0.1,     # Equivalent to 'eta', controls the step size
    max_depth=6,           # Depth of each tree
    subsample=0.8,         # Fraction of samples used per tree (prevents overfitting)
    colsample_bytree=0.8,  # Fraction of features used per tree
    eval_metric='mlogloss'
)
# use_label_encoder=False,

# 3. Fit the model
start_time = time.time()
xgb_model.fit(
    X_train_xgb, y_train,
    eval_set=[(X_test_xgb, y_test)],
    verbose=False
)
end_time = time.time()
spent_time = end_time-start_time

# 4. Evaluation
y_pred_xgb = xgb_model.predict(X_test_xgb)
xgb_accuracy = accuracy_score(y_test, y_pred_xgb)
print(f"XGBoost Training Duration: {spent_time:.2f} s")
print(f"XGBoost Test Accuracy: {xgb_accuracy*100:.2f}%")
# Out:
# XGBoost Training Duration: 34.06 s
# XGBoost Test Accuracy: 82.42%

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

# Base XGB model
xgb_base = xgb.XGBClassifier(
    objective="multi:softprob",
    num_class=10,
    eval_metric="mlogloss",
    use_label_encoder=False,
    tree_method="hist",   # faster & stable
    random_state=42
)

# Parameter distributions (not grids!)
param_distributions = {
    "max_depth": randint(3, 8),
    "min_child_weight": randint(1, 6),
    "gamma": uniform(0, 1.0),
    "subsample": uniform(0.6, 0.4),
    "colsample_bytree": uniform(0.6, 0.4),
    "learning_rate": uniform(0.01, 0.1),
    "n_estimators": randint(200, 1000),
    "reg_alpha": uniform(0, 0.5),
    "reg_lambda": uniform(0.5, 1.5)
}

# Randomized search
random_search = RandomizedSearchCV(
    estimator=xgb_base,
    param_distributions=param_distributions,
    n_iter=40,            # 30–50 is a good balance
    scoring="accuracy",
    cv=3,
    verbose=1,
    random_state=42,
    n_jobs=-1
)

# Fit (no early stopping here – handled after)
start_time = time.time()
random_search.fit(X_train_xgb, y_train)
end_time = time.time()
grid_time = end_time-start_time

# Best model
best_xgb = random_search.best_estimator_

print(f"XGBoost Tuning Duration: {grid_time:.2f} s")
print("Best parameters found:")
print(random_search.best_params_)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:02:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost Tuning Duration: 3528.21 s
# Best parameters found:
# {'colsample_bytree': np.float64(0.6336559859980195), 'gamma': np.float64(0.16162871409461377), 'learning_rate': np.float64(0.09985541885270792), 'max_depth': 6, 'min_child_weight': 3, 'n_estimators': 311, 'reg_alpha': np.float64(0.05073577143301605), 'reg_lambda': np.float64(1.4952526536620838), 'subsample': np.float64(0.6020246335384875)}

# %%
# We set objective to 'multi:softprob' for multi-class classification
xgb_model = xgb.XGBClassifier(
    n_estimators=311,      # Number of boosting rounds (trees)
    learning_rate=0.1,     # Equivalent to 'eta', controls the step size
    reg_alpha = 0.05,
    reg_lambda = 1.5,
    max_depth=6,           # Depth of each tree
    min_child_weight = 3,
    gamma = 0.16,
    subsample=0.6,         # Fraction of samples used per tree (prevents overfitting)
    colsample_bytree=0.633,  # Fraction of features used per tree
    use_label_encoder=False,
    eval_metric='mlogloss'
)

# 3. Fit the model
start_time = time.time()
xgb_model.fit(
    X_train_xgb, y_train,
    eval_set=[(X_test_xgb, y_test)],
    verbose=False
)
end = time.time()
training_time = end_time-start_time
# 4. Evaluation
y_pred_xgb = xgb_model.predict(X_test_xgb)
xgb_accuracy = accuracy_score(y_test, y_pred_xgb)
print(f"XGBoost Training Duration: {training_time:.2f} s")
print(f"XGBoost Test Accuracy: {xgb_accuracy*100:.2f}%")
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [16:02:44] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost Training Duration: -0.26 s
# XGBoost Test Accuracy: 84.83%

# %%
# Define range
data_sizes = range(1000, 11000, 1000)
xgb_results = []

print(f"{'Data Size':<12} | {'XGB Accuracy (%)':<18} | {'Time Spent (s)':<18}")
print("-" * 35)

for size in data_sizes:
    # Slice the training data
    X_subset = X_train_xgb[:size, :]
    y_subset = y_train[:size]

    # Initialize with your specific hyperparameters
    xgb_loop_model = xgb.XGBClassifier(
        n_estimators=311,
        learning_rate=0.1,
        reg_alpha=0.05,
        reg_lambda=1.5,
        max_depth=6,
        min_child_weight=3,
        gamma=0.16,
        subsample=0.6,
        colsample_bytree=0.633,
        eval_metric='mlogloss',
        random_state=42 # Ensures reproducibility
    )

    # 3. Fit the model
    # We use a smaller eval_set for speed, or just the full test set
    start_time = time.time()
    xgb_loop_model.fit(
        X_subset, y_subset,
        eval_set=[(X_test_xgb, y_test)],
        verbose=False
    )
    end_time = time.time()
    spent_time = end_time-start_time

    # 4. Evaluation
    y_pred_xgb = xgb_loop_model.predict(X_test_xgb)
    acc = accuracy_score(y_test, y_pred_xgb) * 100

    xgb_results.append((size, acc))
    print(f"{size:<12} | {acc:<18.2f} | {spent_time:<18.2f}")

xgb_results_arr = np.array(xgb_results)
# Out:
# Data Size    | XGB Accuracy (%)   | Time Spent (s)
# -----------------------------------
# 1000         | 66.17              | 5.69
# 2000         | 73.67              | 10.91
# 3000         | 77.75              | 13.83
# 4000         | 79.42              | 16.25
# 5000         | 79.25              | 21.01
# 6000         | 81.00              | 23.26
# 7000         | 81.92              | 25.14
# 8000         | 83.17              | 26.20
# 9000         | 83.33              | 28.02
# 10000        | 84.08              | 30.65
